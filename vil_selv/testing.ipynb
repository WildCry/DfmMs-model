# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from fredwrapper import FetchFred
from preprocessing import preprocess_data

# %%
fred = FetchFred(api_key='d59606a150e09c54fd5158bac863da0d')

data = fred.fetch()
data = data.dropna()

# %%
data.plot(figsize=(15,5))
plt.show()

# %%
data
# Out:
#                     MTS    PILTP      ENAP     IPMAN
# 1972-01-01   436061.565   4208.2   72441.0   35.9488
# 1972-02-01   431354.862   4231.9   72648.0   36.2194
# 1972-03-01   439346.765   4259.5   72944.0   36.4664
# 1972-04-01   442331.562   4273.3   73162.0   36.8786
# 1972-05-01   445055.610   4291.2   73469.0   36.9454
# ...                 ...      ...       ...       ...
# 2023-08-01  1497717.000  15726.6  156421.0   99.9193
# 2023-09-01  1507530.000  15741.9  156667.0  100.1165
# 2023-10-01  1505477.000  15784.6  156832.0   99.3856
# 2023-11-01  1514733.000  15859.9  157014.0  100.0087
# 2023-12-01  1530296.000  15899.0  157304.0  100.0745
#
# [624 rows x 4 columns]

# %%
y = preprocess_data(data)

y.dropna().plot(figsize=(15,5))
plt.show()
